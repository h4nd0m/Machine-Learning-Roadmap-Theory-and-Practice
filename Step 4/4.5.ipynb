# %%
# 1. Полиномиальные признаки (Interaction Features)
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_poly = poly.fit_transform(X[['Floor', 'Has_Elevator']])
# Eсли на входе были столбцы [a, b], 
# то на выходе мы получим: [a, b, a * b]

# %%
# 2. Базовая предобработка текста (Text Features)

# 1) Bag of Words / BoW («Мешок слов»)
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features=100) 
# берём только 100 самых популярных слов из текста
X_text = vectorizer.fit_transform(df['Description'])
# возвращает словарь сколько кадое слово встретилось в объявлении

# %%
# 2) TF-IDF (Term Frequency - Inverse Document Frequency)
# проблема мешка слов, что там всегда есть частые слова по типу и а но в и т.д.

TF-IDF = TF * IDF
# TF (Term Frequency): Как часто слово встречается в текущем тексте.
# IDF (Inverse Document Frequency): 
# Насколько это слово редкое во всех текстах вообще.
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=50, stop_words='english')
X_tfidf = tfidf.fit_transform(df['Description'])
